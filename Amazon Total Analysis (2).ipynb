# %%
import pandas as pd

# Replace 'Analysis.csv' with the actual file path
filename = 'Amazon Analysis.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filename)

# Display the DataFrame
print(df)
# Out:
#                                             Articles  Overall Sentiment   \
# 0   AXA and AWS Developing the First Global B2B Ri...           Positive
# 1   Announcing AWS Deadline Cloud, a New Service t...           Positive
# 2   BrainBox AI Introduces ARIA: The World’s First...           Positive
# 3   Upstage Launches Small Language Model on AWS t...           Positive
# 4   Compute for Climate Fellowship Announces Inaug...           Positive
# ..                                                ...                ...
# 95  Sumitomo Corporation Selects AWS to Drive Its ...           Positive
# 96  Occidental Selects AWS as Its Preferred Cloud ...           Positive
# 97  AWS Announces AWS HealthScribe, a New Generati...           Positive
# 98  AWS Announces the General Availability of AWS ...           Positive
# 99  AWS Expands Amazon Bedrock With Additional Fou...           Positive
#
#     Positive Sentiment Score   Negative Sentiment Score   \
# 0                        0.15                       0.06
# 1                        0.11                       0.02
# 2                        0.19                       0.01
# 3                        0.14                       0.01
# 4                        0.16                       0.02
# ..                        ...                        ...
# 95                       0.12                       0.01
# 96                       0.20                       0.01
# 97                       0.14                       0.02
# 98                       0.17                       0.02
# 99                       0.16                       0.01
#
#     Neutral Sentiment Score   Amount in Dollars Change in MC  \
# 0                       0.79                        5.070007
# 1                       0.87                        1.720001
# 2                       0.80                        1.529999
# 3                       0.86                        0.720001
# 4                       0.82                        0.720001
# ..                       ...                             ...
# 95                      0.87                       -1.989990
# 96                      0.79                        3.960007
# 97                      0.84                        0.100006
# 98                      0.81                        0.100006
# 99                      0.83                        0.100006
#
#    Percentage Change inMC       Date    Open    High     Low   Close
# 0                    2.82%   4/4/2024  184.00  185.10  180.00  180.00
# 1                    0.95%   4/2/2024  179.07  180.79  178.38  180.69
# 2                    0.86%  3/26/2024  180.15  180.45  177.95  178.30
# 3                    0.40%  3/21/2024  179.99  181.42  178.15  178.15
# 4                    0.40%  3/21/2024  179.99  181.42  178.15  178.15
# ..                     ...        ...     ...     ...     ...     ...
# 95                  -1.49%  7/31/2023  133.20  133.87  132.38  133.68
# 96                   3.09%  7/27/2023  131.00  132.63  127.79  128.25
# 97                   0.08%  7/26/2023  126.51  129.08  126.11  128.15
# 98                   0.08%  7/26/2023  126.51  129.08  126.11  128.15
# 99                   0.08%  7/26/2023  126.51  129.08  126.11  128.15
#
# [100 rows x 12 columns]

# %%
import numpy as np
#Replace '?' with 'NaN'
df.replace('?',np.nan, inplace = True)
df.head(10)
# Out:
#                                            Articles  Overall Sentiment   \
# 0  AXA and AWS Developing the First Global B2B Ri...           Positive
# 1  Announcing AWS Deadline Cloud, a New Service t...           Positive
# 2  BrainBox AI Introduces ARIA: The World’s First...           Positive
# 3  Upstage Launches Small Language Model on AWS t...           Positive
# 4  Compute for Climate Fellowship Announces Inaug...           Positive
# 5  DFL Deutsche Fußball Liga and Amazon Web Servi...           Positive
# 6  Danske Bank invests in cloud technology and si...           Positive
# 7  AWS and NVIDIA Extend Collaboration to Advance...           Positive
# 8  AWS to Launch an Infrastructure Region in the ...           Positive
# 9  NTT DOCOMO Selects AWS to Deploy Nationwide 5G...           Positive
#
#    Positive Sentiment Score   Negative Sentiment Score   \
# 0                       0.15                       0.06
# 1                       0.11                       0.02
# 2                       0.19                       0.01
# 3                       0.14                       0.01
# 4                       0.16                       0.02
# 5                       0.14                       0.00
# 6                       0.17                       0.00
# 7                       0.12                       0.01
# 8                       0.18                       0.01
# 9                       0.12                       0.03
#
#    Neutral Sentiment Score   Amount in Dollars Change in MC  \
# 0                      0.79                        5.070007
# 1                      0.87                        1.720001
# 2                      0.80                        1.529999
# 3                      0.86                        0.720001
# 4                      0.82                        0.720001
# 5                      0.86                        0.000000
# 6                      0.83                        0.000000
# 7                      0.88                        1.419998
# 8                      0.81                       -3.460007
# 9                      0.84                       -1.190002
#
#   Percentage Change inMC       Date    Open    High     Low   Close
# 0                   2.82%   4/4/2024  184.00  185.10  180.00  180.00
# 1                   0.95%   4/2/2024  179.07  180.79  178.38  180.69
# 2                   0.86%  3/26/2024  180.15  180.45  177.95  178.30
# 3                   0.40%  3/21/2024  179.99  181.42  178.15  178.15
# 4                   0.40%  3/21/2024  179.99  181.42  178.15  178.15
# 5                   0.00%  3/20/2024  176.14  178.53  174.64  178.15
# 6                   0.00%  3/20/2024  176.14  178.53  174.64  178.15
# 7                   0.81%  3/18/2024  175.80  176.69  174.28  174.48
# 8                  -1.95%   3/4/2024  177.53  180.14  177.49  177.58
# 9                  -0.68%  2/26/2024  175.70  176.37  174.26  174.73

# %%
# Drop rows where all columns are NaN
df_dropped = df.dropna(how='all')
print(df_dropped)
# Out:
#                                             Articles  Overall Sentiment   \
# 0   AXA and AWS Developing the First Global B2B Ri...           Positive
# 1   Announcing AWS Deadline Cloud, a New Service t...           Positive
# 2   BrainBox AI Introduces ARIA: The World’s First...           Positive
# 3   Upstage Launches Small Language Model on AWS t...           Positive
# 4   Compute for Climate Fellowship Announces Inaug...           Positive
# ..                                                ...                ...
# 95  Sumitomo Corporation Selects AWS to Drive Its ...           Positive
# 96  Occidental Selects AWS as Its Preferred Cloud ...           Positive
# 97  AWS Announces AWS HealthScribe, a New Generati...           Positive
# 98  AWS Announces the General Availability of AWS ...           Positive
# 99  AWS Expands Amazon Bedrock With Additional Fou...           Positive
#
#     Positive Sentiment Score   Negative Sentiment Score   \
# 0                        0.15                       0.06
# 1                        0.11                       0.02
# 2                        0.19                       0.01
# 3                        0.14                       0.01
# 4                        0.16                       0.02
# ..                        ...                        ...
# 95                       0.12                       0.01
# 96                       0.20                       0.01
# 97                       0.14                       0.02
# 98                       0.17                       0.02
# 99                       0.16                       0.01
#
#     Neutral Sentiment Score   Amount in Dollars Change in MC  \
# 0                       0.79                        5.070007
# 1                       0.87                        1.720001
# 2                       0.80                        1.529999
# 3                       0.86                        0.720001
# 4                       0.82                        0.720001
# ..                       ...                             ...
# 95                      0.87                       -1.989990
# 96                      0.79                        3.960007
# 97                      0.84                        0.100006
# 98                      0.81                        0.100006
# 99                      0.83                        0.100006
#
#    Percentage Change inMC       Date    Open    High     Low   Close
# 0                    2.82%   4/4/2024  184.00  185.10  180.00  180.00
# 1                    0.95%   4/2/2024  179.07  180.79  178.38  180.69
# 2                    0.86%  3/26/2024  180.15  180.45  177.95  178.30
# 3                    0.40%  3/21/2024  179.99  181.42  178.15  178.15
# 4                    0.40%  3/21/2024  179.99  181.42  178.15  178.15
# ..                     ...        ...     ...     ...     ...     ...
# 95                  -1.49%  7/31/2023  133.20  133.87  132.38  133.68
# 96                   3.09%  7/27/2023  131.00  132.63  127.79  128.25
# 97                   0.08%  7/26/2023  126.51  129.08  126.11  128.15
# 98                   0.08%  7/26/2023  126.51  129.08  126.11  128.15
# 99                   0.08%  7/26/2023  126.51  129.08  126.11  128.15
#
# [100 rows x 12 columns]

# %%
print(df.describe(include='all'))
# Out:
#                                                 Articles  Overall Sentiment   \
# count                                                 100                100
# unique                                                 99                  1
# top     AWS Selected by HD Hyundai Oilbank to Accelera...           Positive
# freq                                                    2                100
# mean                                                  NaN                NaN
# std                                                   NaN                NaN
# min                                                   NaN                NaN
# 25%                                                   NaN                NaN
# 50%                                                   NaN                NaN
# 75%                                                   NaN                NaN
# max                                                   NaN                NaN
#
#         Positive Sentiment Score   Negative Sentiment Score   \
# count                  100.000000                 100.000000
# unique                        NaN                        NaN
# top                           NaN                        NaN
# freq                          NaN                        NaN
# mean                     0.157000                   0.017300
# std                      0.033166                   0.020442
# min                      0.070000                   0.000000
# 25%                      0.137500                   0.010000
# 50%                      0.155000                   0.010000
# 75%                      0.170000                   0.020000
# max                      0.250000                   0.110000
#
#         Neutral Sentiment Score   Amount in Dollars Change in MC  \
# count                 100.000000                      100.000000
# unique                       NaN                             NaN
# top                          NaN                             NaN
# freq                         NaN                             NaN
# mean                    0.824600                       -0.416000
# std                     0.038492                        2.218541
# min                     0.690000                       -7.169998
# 25%                     0.810000                       -1.564997
# 50%                     0.830000                       -0.630005
# 75%                     0.850000                        0.720001
# max                     0.890000                        5.070007
#
#        Percentage Change inMC        Date        Open       High         Low   \
# count                      100         100  100.000000  100.00000  100.000000
# unique                      52          53         NaN        NaN         NaN
# top                     -0.48%  11/28/2023         NaN        NaN         NaN
# freq                        11          11         NaN        NaN         NaN
# mean                       NaN         NaN  146.002500  147.31130  144.518000
# std                        NaN         NaN   13.900148   13.94184   14.009098
# min                        NaN         NaN  124.040000  126.34000  120.790000
# 25%                        NaN         NaN  138.662500  138.84000  135.560000
# 50%                        NaN         NaN  145.130000  147.26000  144.730000
# 75%                        NaN         NaN  147.850000  149.26000  146.880000
# max                        NaN         NaN  184.000000  185.10000  180.000000
#
#             Close
# count   100.000000
# unique         NaN
# top            NaN
# freq           NaN
# mean    145.789500
# std      13.894955
# min     121.390000
# 25%     137.540000
# 50%     146.130000
# 75%     147.730000
# max     180.690000

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Articles                        100 non-null    object
#  1   Overall Sentiment               100 non-null    object
#  2   Positive Sentiment Score        100 non-null    float64
#  3   Negative Sentiment Score        100 non-null    float64
#  4   Neutral Sentiment Score         100 non-null    float64
#  5   Amount in Dollars Change in MC  100 non-null    float64
#  6   Percentage Change inMC          100 non-null    object
#  7   Date                            100 non-null    object
#  8   Open                            100 non-null    float64
#  9   High                            100 non-null    float64
#  10  Low                             100 non-null    float64
#  11  Close                           100 non-null    float64
# dtypes: float64(8), object(4)
# memory usage: 9.5+ KB
# None

# %%
#Count missing values in each column
missing_data = df.isnull()
missing_data.head(5)
#Using a for loop in Python, you can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value and "False" means the value is present in the data set. In the body of the for loop the method ".value_counts()" counts the number of "True" values.
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Articles
# Articles
# False    100
# Name: count, dtype: int64
#
# Overall Sentiment
# Overall Sentiment
# False    100
# Name: count, dtype: int64
#
# Positive Sentiment Score
# Positive Sentiment Score
# False    100
# Name: count, dtype: int64
#
# Negative Sentiment Score
# Negative Sentiment Score
# False    100
# Name: count, dtype: int64
#
# Neutral Sentiment Score
# Neutral Sentiment Score
# False    100
# Name: count, dtype: int64
#
# Amount in Dollars Change in MC
# Amount in Dollars Change in MC
# False    100
# Name: count, dtype: int64
#
# Percentage Change inMC
# Percentage Change inMC
# False    100
# Name: count, dtype: int64
#
# Date
# Date
# False    100
# Name: count, dtype: int64
#
# Open
# Open
# False    100
# Name: count, dtype: int64
#
# High
# High
# False    100
# Name: count, dtype: int64
#
# Low
# Low
# False    100
# Name: count, dtype: int64
#
# Close
# Close
# False    100
# Name: count, dtype: int64

# %%
# Print the column names to verify
print(df.columns)
# Out:
# Index(['Articles ', 'Overall Sentiment ', 'Positive Sentiment Score ',
#        'Negative Sentiment Score ', 'Neutral Sentiment Score ',
#        'Amount in Dollars Change in MC', 'Percentage Change inMC ', 'Date ',
#        'Open ', 'High ', 'Low ', 'Close '],
#       dtype='object')

# %%
import pandas as pd

# Remove the '%' symbol and convert to float
df['Percentage Change inMC '] = df['Percentage Change inMC '].str.replace('%', '').astype(float)

# %%
df[['Positive Sentiment Score ',
       'Negative Sentiment Score ', 'Neutral Sentiment Score ',
       'Percentage Change inMC ', 'Amount in Dollars Change in MC']].corr()
# Out:
#                                 Positive Sentiment Score   \
# Positive Sentiment Score                         1.000000
# Negative Sentiment Score                         0.053485
# Neutral Sentiment Score                         -0.795330
# Percentage Change inMC                          -0.081769
# Amount in Dollars Change in MC                  -0.086746
#
#                                 Negative Sentiment Score   \
# Positive Sentiment Score                         0.053485
# Negative Sentiment Score                         1.000000
# Neutral Sentiment Score                         -0.565569
# Percentage Change inMC                          -0.014062
# Amount in Dollars Change in MC                  -0.005862
#
#                                 Neutral Sentiment Score   \
# Positive Sentiment Score                       -0.795330
# Negative Sentiment Score                       -0.565569
# Neutral Sentiment Score                         1.000000
# Percentage Change inMC                          0.085311
# Amount in Dollars Change in MC                  0.088093
#
#                                 Percentage Change inMC   \
# Positive Sentiment Score                      -0.081769
# Negative Sentiment Score                      -0.014062
# Neutral Sentiment Score                        0.085311
# Percentage Change inMC                         1.000000
# Amount in Dollars Change in MC                 0.995390
#
#                                 Amount in Dollars Change in MC
# Positive Sentiment Score                             -0.086746
# Negative Sentiment Score                             -0.005862
# Neutral Sentiment Score                               0.088093
# Percentage Change inMC                                0.995390
# Amount in Dollars Change in MC                        1.000000

# %%
import seaborn as sns

# %%
sns.regplot(x="Positive Sentiment Score ", y="Percentage Change inMC ", data=df)
# Out:
# <Axes: xlabel='Positive Sentiment Score ', ylabel='Percentage Change inMC '>

# %%
sns.regplot(x="Negative Sentiment Score ", y="Percentage Change inMC ", data=df)
# Out:
# <Axes: xlabel='Negative Sentiment Score ', ylabel='Percentage Change inMC '>

# %%
sns.regplot(x="Neutral Sentiment Score ", y="Percentage Change inMC ", data=df)
# Out:
# <Axes: xlabel='Neutral Sentiment Score ', ylabel='Percentage Change inMC '>

# %%
sns.regplot(x="Amount in Dollars Change in MC", y="Percentage Change inMC ", data=df)
# Out:
# <Axes: xlabel='Amount in Dollars Change in MC', ylabel='Percentage Change inMC '>

# %%
df['Percentage Change inMC '].value_counts()
# Out:
# Percentage Change inMC
# -0.48    11
# -0.47     9
# -0.16     9
# -1.53     4
#  0.08     3
#  0.64     3
# -1.70     3
#  0.00     3
# -4.41     3
# -1.78     3
#  2.56     2
# -0.44     2
# -0.26     2
#  0.38     2
# -1.40     2
#  0.40     2
# -0.68     2
#  1.13     1
# -1.39     1
# -4.03     1
#  0.81     1
# -1.68     1
# -0.09     1
#  0.86     1
#  1.84     1
#  2.18     1
# -0.82     1
#  0.12     1
#  1.08     1
#  0.52     1
# -2.64     1
# -1.49     1
#  3.09     1
#  0.90     1
#  1.59     1
#  1.52     1
# -1.95     1
#  0.94     1
# -0.36     1
#  1.65     1
#  2.71     1
#  2.11     1
# -1.04     1
#  2.13     1
# -1.92     1
#  0.95     1
#  2.94     1
# -1.50     1
# -5.58     1
#  1.58     1
# -2.54     1
#  2.82     1
# Name: count, dtype: int64

# %%
import matplotlib as plt
import pandas as pd

# %%
print(df.columns)
# Out:
# Index(['Articles', 'Overall Sentiment', 'Positive Sentiment Score',
#        'Negative Sentiment Score', 'Neutral Sentiment Score',
#        'Amount in Dollars Change in MC', 'Percentage Change inMC', 'Date',
#        'Open', 'High', 'Low', 'Close'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

filename = 'Amazon Analysis.csv'

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(filename)

df.columns = df.columns.str.strip()

# Convert the 'Date' column to string data type
df['Date'] = df['Date'].astype(str)

# Plot the data
plt.figure(figsize=(20, 20))  # Set a reasonable figure size
plt.plot(df['Date'], df['Amount in Dollars Change in MC'], marker='o', linestyle='-')
plt.title('Stock Price change in dollars Over Time')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Articles', 'Overall Sentiment', 'Positive Sentiment Score',
#        'Negative Sentiment Score', 'Neutral Sentiment Score',
#        'Amount in Dollars Change in MC', 'Percentage Change inMC', 'Date',
#        'Open', 'High', 'Low', 'Close'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# Load your data into a DataFrame
dataframe = pd.read_csv("Amazon Analysis.csv")

# Replace '?' with 'NaN'
dataframe.replace('?', np.nan, inplace=True)

# Drop rows with NaN values
dataframe.dropna(inplace=True)

# Calculate Pearson correlation coefficient and p-value
pearson_coef, p_value = stats.pearsonr(dataframe['Positive Sentiment Score '], dataframe['Amount in Dollars Change in MC'])

# Print the results
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.08674633545714036 with a P-value of P = 0.3907950481892965

# %%
# Calculate Pearson correlation coefficient and p-value
pearson_coef, p_value = stats.pearsonr(dataframe['Negative Sentiment Score '], dataframe['Amount in Dollars Change in MC'])

# Print the results
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.005861596784937292 with a P-value of P = 0.9538446053449225

# %%
# Calculate Pearson correlation coefficient and p-value
pearson_coef, p_value = stats.pearsonr(dataframe['Neutral Sentiment Score '], dataframe['Amount in Dollars Change in MC'])

# Print the results
print("The Pearson Correlation Coefficient is", pearson_coef, "with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.08809266195814972 with a P-value of P = 0.3834554344439722

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
# %matplotlib inline

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# Load your data into a DataFrame
dataframe = pd.read_csv("Analysis.csv")

# Replace '?' with 'NaN'
dataframe.replace('?', np.nan, inplace=True)

# Drop rows with NaN values
dataframe.dropna(inplace=True)

# %%
lm = LinearRegression()

X = dataframe[['Positive Sentiment Score ']]
Y = dataframe['Amount in Dollars Change inMC ']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax1 = sns.distplot(dataframe['Amount in Dollars Change inMC '], hist=False, color="r", label="Actual Values")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Amount in Dollars Change inMC ')
plt.ylabel('Postive Sentiment Score')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()

# %%
lm = LinearRegression()

X = dataframe[['Negative Sentiment Score ']]
Y = dataframe['Amount in Dollars Change inMC ']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax1 = sns.distplot(dataframe['Amount in Dollars Change inMC '], hist=False, color="r", label="Actual Values")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Amount in Dollars Change inMC ')
plt.ylabel('Negative Sentiment Score')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()

# %%
lm = LinearRegression()

X = dataframe[['Neutral Sentiment Score ']]
Y = dataframe['Amount in Dollars Change inMC ']

lm.fit(X,Y)

Yhat=lm.predict(X)

# %%
ax1 = sns.distplot(dataframe['Amount in Dollars Change inMC '], hist=False, color="r", label="Actual Values")

# Create a distribution plot for predicted values
sns.distplot(Yhat, hist=False, color="b", label="Fitted Values" , ax=ax1)

plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Amount in Dollars Change inMC ')
plt.ylabel('Neutral Sentiment Score')
plt.legend(['Actual Value', 'Predicted Value'])
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset into a pandas DataFrame
data = pd.read_csv("Amazon Analysis.csv")
df = pd.DataFrame(data)

# Drop rows with NaN values in-place
df.dropna(inplace=True)

# %%
# Assign 'Positive Sentiment Score' as the feature (X)
X = df['Positive Sentiment Score '].values.reshape(-1, 1)

# Assign 'Close' as the target variable (y)
y = df['Close '].values

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions on the training data
y_pred = model.predict(X)

# Compute Mean Squared Error (MSE)
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

# Compute R-squared
r2 = r2_score(y, y_pred)
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Squared Error: 190.57
# R-squared: 0.00

# %%
# Assign 'Positive Sentiment Score' as the feature (X)
X = df['Negative Sentiment Score '].values.reshape(-1, 1)

# Assign 'Close' as the target variable (y)
y = df['Close '].values

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions on the training data
y_pred = model.predict(X)

# Compute Mean Squared Error (MSE)
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

# Compute R-squared
r2 = r2_score(y, y_pred)
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Squared Error: 188.86
# R-squared: 0.01

# %%
# Assign 'Positive Sentiment Score' as the feature (X)
X = df['Neutral Sentiment Score '].values.reshape(-1, 1)

# Assign 'Close' as the target variable (y)
y = df['Close '].values

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions on the training data
y_pred = model.predict(X)

# Compute Mean Squared Error (MSE)
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

# Compute R-squared
r2 = r2_score(y, y_pred)
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Squared Error: 188.26
# R-squared: 0.02

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Load the dataset into a pandas DataFrame
data = pd.read_csv('Amazon Analysis.csv')
df = pd.DataFrame(data)

df = df.dropna(how='any')

# Assign multiple columns as features (X)
X = df[['Positive Sentiment Score ', 'Open ', 'High ', 'Low ']]

# Assign 'Close ' as the target variable (y)
y = df['Close '].values

# Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# Make predictions on the training data
y_pred = model.predict(X)

# Compute Mean Squared Error (MSE)
mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error: {mse:.2f}")

# Compute R-squared
r2 = r2_score(y, y_pred)
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Squared Error: 0.53
# R-squared: 1.00

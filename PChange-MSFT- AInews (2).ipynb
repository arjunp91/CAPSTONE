# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-02-16", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-02-16", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change_dollars)

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -0.31% after the article was published.
# -1.269989013671875

# %% [markdown]
# Deceptive role of AI Tools on Elections

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-01-15", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-01-15", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change_dollars)

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 0.26% after the article was published.
# 0.998138427734375

# %% [markdown]
# "Vodafone and Microsoft sign 10-year strategic partnership to bring generative AI, digital services and the cloud to more than 300 million businesses and consumers"

# %%
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-12-11", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-12-11", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 0.83% after the article was published.

# %% [markdown]
# AFL-CIO and Microsoft announce new tech labor partnership on AI and the future of the workforce

# %% [markdown]
# The only change from the previous code is the article_date, which is now set to 2023-12-11 to correspond to the date of the new article.
#
# When you run this code, it will fetch the Microsoft stock data for the last 6 months, calculate the percentage change in the stock price after the article date (2023-12-11), print the percentage change, and plot the stock price with a vertical line indicating the article date.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-12-11", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-12-11", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change_dollars)

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 0.83% after the article was published.
# 3.0743408203125

# %% [markdown]
# AFL-CIO and Microsoft announce new tech labor partnership on AI and the future of the workforce"

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-01-30", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-01-30", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change_dollars)

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -2.69% after the article was published.
# -10.98968505859375

# %% [markdown]
# "Microsoft Cloud Strength Drives Second Quarter Results" on Microsoft's stock price

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-03-05", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-03-05", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change_dollars)

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -0.14% after the article was published.
# -0.55999755859375

# %% [markdown]
# "Educators and students now have a secure AI scaffolding to support them in the classroom" on Microsoft's stock price

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-03-03", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-03-03", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change_dollars)

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -3.09% after the article was published.
# -12.850006103515625

# %% [markdown]
# "India's schoolteachers are drafting better lesson plans faster, thanks to a Copilot" on Microsoft's stock price

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-03-06", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-03-06", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

#Price change in dollars for the stock
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Calculate the percentage change in stock price
price_change = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Print the percentage change
print(f"The stock price of Microsoft changed by {price_change:.2f}% after the article was published.")
print(price_change)


# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 1.75% after the article was published.
# 1.7533433745569964

# %% [markdown]
# "Microsoft launches AI Odyssey to skill 100,000 developers in India in latest AI technologies and tools" on Microsoft's stock price:

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-01-09", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-01-09", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Calculate the dollar change in stock price
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 1.86% ($6.97) after the article was published.

# %% [markdown]
# Walmart unveils new generative AI-powered capabilities for shoppers and associates

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-01-04", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-01-04", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Calculate the dollar change in stock price
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -0.05% ($-0.19) after the article was published.

# %% [markdown]
# Introducing a new Copilot key to kick off the year of AI-powered Windows PCs

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-12-05", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-12-05", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Calculate the dollar change in stock price
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -1.00% ($-3.71) after the article was published.

# %% [markdown]
# Celebrating the first year of Copilot with significant new innovations

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-11-07", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-11-07", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Calculate the dollar change in stock price
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 0.74% ($2.66) after the article was published.

# %% [markdown]
# Startups to access high-performance Azure infrastructure, accelerating AI breakthroughs

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-11-22", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-11-22", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Calculate the dollar change in stock price
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by -0.11% ($-0.42) after the article was published.

# %% [markdown]
# With a systems approach to chips, Microsoft aims to tailor everything ‘from silicon to service’ to meet AI demand

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-10-10", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-10-10", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100

# Calculate the dollar change in stock price
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 1.23% ($4.01) after the article was published.

# %% [markdown]
# Microsoft introduces new data and AI solutions to help healthcare organizations unlock insights and improve patient and clinician experiences

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="3mo")  # Adjust the period to include the article date

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-03-11", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-03-11", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
if len(after_article) >= 2:
    price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100
else:
    print("Not enough data after the article date to calculate the percentage change.")
    price_change_percent = None

# Calculate the dollar change in stock price
if len(after_article) >= 2:
    price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]
else:
    print("Not enough data after the article date to calculate the dollar change.")
    price_change_dollars = None

# Print the changes
if price_change_percent is not None and price_change_dollars is not None:
    print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# Not enough data after the article date to calculate the percentage change.
# Not enough data after the article date to calculate the dollar change.

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")  # Adjust the period to include the article date

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-01-24", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-01-24", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
if len(after_article) >= 2:
    price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100
else:
    print("Not enough data after the article date to calculate the percentage change.")
    price_change_percent = None

# Calculate the dollar change in stock price
if len(after_article) >= 2:
    price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]
else:
    print("Not enough data after the article date to calculate the dollar change.")
    price_change_dollars = None

# Print the changes
if price_change_percent is not None and price_change_dollars is not None:
    print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 0.57% ($2.31) after the article was published.

# %% [markdown]
# Broadening AI innovation: Microsoft’s pledge to the National AI Research Resource pilot

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="6mo")  # Adjust the period to include the article date

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2024-03-11", tz="America/New_York")
else:
    article_date = pd.Timestamp("2024-03-11", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
if len(after_article) >= 2:
    price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100
else:
    print("Not enough data after the article date to calculate the percentage change.")
    price_change_percent = None

# Calculate the dollar change in stock price
if len(after_article) >= 2:
    price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]
else:
    print("Not enough data after the article date to calculate the dollar change.")
    price_change_dollars = None

# Print the changes
if price_change_percent is not None and price_change_dollars is not None:
    print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 2.66% ($10.76) after the article was published.

# %% [markdown]
# Microsoft makes the promise of AI in healthcare real through new collaborations with healthcare organizations and partners

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from pandas.compat import PY310

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="1y")  # Adjust the period to include the article date

# Convert the date of the article to a pandas datetime object
# Specify the timezone (e.g., 'America/New_York')
if PY310:
    article_date = pd.Timestamp("2023-12-14", tz="America/New_York")
else:
    article_date = pd.Timestamp("2023-12-14", tz=pd.Timezone("America/New_York"))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]

# Calculate the percentage change in stock price
if len(after_article) >= 2:
    price_change_percent = (after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100
else:
    print("Not enough data after the article date to calculate the percentage change.")
    price_change_percent = None

# Calculate the dollar change in stock price
if len(after_article) >= 2:
    price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]
else:
    print("Not enough data after the article date to calculate the dollar change.")
    price_change_dollars = None

# Print the changes
if price_change_percent is not None and price_change_dollars is not None:
    print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 1.31% ($4.79) after the article was published.

# %% [markdown]
# Research at Microsoft 2023: A year of groundbreaking AI advances and discoveries

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# Fetch Microsoft stock data
msft = yf.Ticker("MSFT")
msft_data = msft.history(period="10y")  # Adjust the period to include the article date

# Convert the date of the article to a pandas datetime object
article_date = pd.Timestamp("2023-01-23", tz="America/New_York")

# Reindex the DataFrame to include the article_date
msft_data = msft_data.reindex(msft_data.index.union([article_date]))

# Calculate the stock price difference before and after the article date
before_article = msft_data.loc[:article_date]
after_article = msft_data.loc[article_date:]
price_change_percent = (msft_data.loc[article_date, "Close"] - before_article["Close"].iloc[-1]) / before_article["Close"].iloc[-1] * 100
price_change_dollars = after_article["Close"].iloc[1] - before_article["Close"].iloc[-1]

# Print the changes
if price_change_percent is not None and price_change_dollars is not None:
    print(f"The stock price of Microsoft changed by {price_change_percent:.2f}% (${price_change_dollars:.2f}) after the article was published.")

# Plot the stock data
plt.figure(figsize=(12, 6))
plt.plot(msft_data.index, msft_data["Close"])
plt.axvline(article_date, color="r", linestyle="--", label="Article Date")
plt.title("Microsoft Stock Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.legend()
plt.show()
# Out:
# The stock price of Microsoft changed by 0.00% ($-0.53) after the article was published.

# %% [markdown]
# AI Article with insignificant effect on the stock price
